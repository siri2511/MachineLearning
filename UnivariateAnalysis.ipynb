# %% [markdown]
# <a href="https://colab.research.google.com/github/siri2511/MachineLearning/blob/main/UnivariateAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('train.csv')

# %%
df.head()

# %% [markdown]
# ### **CATEGORICAL DATA**
# A. Countplot

# %%
sns.countplot(df['Survived'])
df['Survived'].value_counts()

# %%
df['Survived'].value_counts().plot(kind='bar')

# %%
sns.countplot(df['Pclass'])

# %%
sns.countplot(df['Sex'])

# %%
sns.countplot(df['Embarked'])

# %% [markdown]
# B. PieChart

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%.2f')

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')

# %% [markdown]
# ### **NUMERICAL DATA**
# A. Histogram

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'])

# %%
plt.hist(df['Age'],bins=5)

# %% [markdown]
# B. Distplot

# %%
sns.distplot(df['Age'])
#curved line is called Kernel Density Estimate

# %% [markdown]
# C. Boxplot

# %%
sns.bloxplot(df['Fare'])

# %%
sns.bloxplot(df['Age'])

# %% [markdown]
# ### **OTHER OPERATIONS**

# %%
df['Age'].min()

# %%
df['Age'].max()

# %%
df['Age'].median()

# %%
df['Age'].skew()
